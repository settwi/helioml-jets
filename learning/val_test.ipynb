# %% [markdown]
# # Idfk what i am doing

# %%
from ultralytics import YOLO

model = YOLO("runs/obb/train3/weights/best.pt")  # load a custom-trained model

# %%
model.val()
# Out:
# Ultralytics 8.3.237 🚀 Python-3.13.7 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 7837MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 7230.7±795.9 MB/s, size: 1408.3 KB)
# val: Scanning /home/william/dev/helioml-jets/learning/dec13-obb/labels.cache... 3689 images, 0 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 3689/3689 10.2Mit/s 0.0s
# val: /home/william/dev/helioml-jets/learning/dec13-obb/images/2011-03-20T08-48-09_70439069_8.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1776 1.835 ]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 231/231 18.5it/s 12.5s0.1s
#                    all       3688       3688      0.573      0.537      0.545      0.232
# Speed: 0.2ms preprocess, 1.3ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /home/william/dev/helioml-jets/runs/obb/val
# ultralytics.utils.metrics.OBBMetrics object with attributes:
#
# ...

# %%
res = model.predict(
    source="dec13-obb/autosplit_test.txt",
    stream=True,
    conf=0.4,
    iou=0.5
)
res
# Out:
# <generator object BasePredictor.stream_inference at 0x798f270fa7a0>
